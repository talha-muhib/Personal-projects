# %%
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print(torch.__version__)
# Out:
# 2.2.1+cu121

# %% [markdown]
# Intro to Tensors

# %%
scalar = torch.tensor(7)
scalar
# Out:
# tensor(7)

# %%
scalar.ndim

# %%
vector = torch.tensor([7, 7])
